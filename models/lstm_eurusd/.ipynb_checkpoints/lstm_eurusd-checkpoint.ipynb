# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

from subprocess import check_output
print(check_output(["ls", "../../data/input"]).decode("utf8"))
# Out:
# BTC_XRP_5min.csv
# EURUSD_15m_BID_sample.csv
# EURUSD_Candlestick_15_M_ASK_01.01.2017-20.07.2018.csv
# EURUSD_Candlestick_15_M_BID_01.01.2017-20.07.2018.csv
# README.md
# stocks.csv

# %%
d_parser = (lambda dt: datetime.strptime(dt[:-4], '%d.%m.%Y %H:%M:%S'))
df = pd.read_csv("../../input/data/EURUSD_NORMALIZED_FEATURED.csv", sep=',', header=0, index_col=0, parse_dates=['Time'], date_parser=d_parser)
df = df.astype(float)
df.head()

# %%
df.count()
# Out:
# Gmt time    38880
# Open        38880
# High        38880
# Low         38880
# Close       38880
# Volume      38880
# dtype: int64

# %%
df.index.min(), df.index.max()
# Out:
# (0, 38879)

# %%
# Rename bid OHLC columns
# df.rename(columns={'Time' : 'timestamp', 'Open' : 'open', 'Close' : 'close', 
#                    'High' : 'high', 'Low' : 'low', 'Close' : 'close', 'Volume' : 'volume'}, inplace=True)
# df['timestamp'] = pd.to_datetime(df['timestamp'], infer_datetime_format=True)
# df.set_index('timestamp', inplace=True)
# df = df.astype(float)
# df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/qizhu/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-933f0c492269> in <module>()
#       3                    'High' : 'high', 'Low' : 'low', 'Close' : 'close', 'Volume' : 'volume'}, inplace=True)
#       4 #df['timestamp'] = pd.to_datetime(df['timestamp'], infer_datetime_format=True)
# ----> 5 df['timestamp'] = pd.to_datetime(df['timestamp'], format="%d.%m.%Y %H%M%S")
#       6 #df.set_index('timestamp', inplace=True)
#       7 #df = df.astype(float)
#
# /Users/qizhu/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# /Users/qizhu/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# /Users/qizhu/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# /Users/qizhu/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/qizhu/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'timestamp'

# %%
# Add additional features
df['hour'] = df.index.hour
df['day']  = df.index.weekday
df['week'] = df.index.week
df['momentum']  = df['volume'] * (df['open'] - df['close'])
df['avg_price'] = (df['low'] + df['high'])/2
df['range']     = df['high'] - df['low']
df['ohlc_price'] = (df['low'] + df['high'] + df['open'] + df['close'])/4
df['oc_diff']    = df['open'] - df['close']

# Cannot add ASK related features, which will limit the accuracy of the model

# %%
# Add PCA as a feature instead of for reducing the dimensionality. This improves the accuracy a bit.
from sklearn.decomposition import PCA

dataset = df.copy().values.astype('float32')
pca_features = df.columns.tolist()

pca = PCA(n_components=1)
df['pca'] = pca.fit_transform(dataset)

# %%
import matplotlib.colors as colors
import matplotlib.cm as cm
import pylab

plt.figure(figsize=(10,5))
norm = colors.Normalize(df['ohlc_price'].values.min(), df['ohlc_price'].values.max())
color = cm.viridis(norm(df['ohlc_price'].values))
plt.scatter(df['ohlc_price'].values, df['pca'].values, lw=0, c=color, cmap=pylab.cm.cool, alpha=0.3, s=1)
plt.title('ohlc_price vs pca')
plt.show()

plt.figure(figsize=(10,5))
norm = colors.Normalize(df['volume'].values.min(), df['volume'].values.max())
color = cm.viridis(norm(df['volume'].values))
plt.scatter(df['volume'].values, df['pca'].values, lw=0, c=color, cmap=pylab.cm.cool, alpha=0.3, s=1)
plt.title('volume vs pca')
plt.show()

plt.figure(figsize=(10,5))
norm = colors.Normalize(df['ohlc_price'].values.min(), df['ohlc_price'].values.max())
color = cm.viridis(norm(df['ohlc_price'].values))
plt.scatter(df['ohlc_price'].shift().values, df['pca'].values, lw=0, c=color, cmap=pylab.cm.cool, alpha=0.3, s=1)
plt.title('ohlc_price - 15min future vs pca')
plt.show()

plt.figure(figsize=(10,5))
norm = colors.Normalize(df['volume'].values.min(), df['volume'].values.max())
color = cm.viridis(norm(df['volume'].values))
plt.scatter(df['volume'].shift().values, df['pca'].values, lw=0, c=color, cmap=pylab.cm.cool, alpha=0.3, s=1)
plt.title('volume - 15min future vs pca')
plt.show()

# %%
df.head()
# Out:
#                         open     high      low    close        volume  hour  \
# timestamp
# 2015-12-29 00:00:00  1.09746  1.09783  1.09741  1.09772  4.866800e+08     0
# 2015-12-29 00:15:00  1.09772  1.09800  1.09770  1.09790  4.459200e+08     0
# 2015-12-29 00:30:00  1.09790  1.09805  1.09782  1.09792  1.210700e+09     0
# 2015-12-29 00:45:00  1.09792  1.09825  1.09775  1.09808  1.116910e+09     0
# 2015-12-29 01:00:00  1.09808  1.09824  1.09791  1.09822  5.038800e+08     1
#
#                      day  week       momentum  avg_price    range  ohlc_price  \
# timestamp
# 2015-12-29 00:00:00    1    53 -126536.800832   1.097620  0.00042    1.097605
# 2015-12-29 00:15:00    1    53  -80265.599838   1.097850  0.00030    1.097830
# 2015-12-29 00:30:00    1    53  -24214.000100   1.097935  0.00023    1.097923
# 2015-12-29 00:45:00    1    53 -178705.598720   1.098000  0.00050    1.098000
# 2015-12-29 01:00:00    1    53  -70543.200420   1.098075  0.00033    1.098113
#
#                      oc_diff           pca
# timestamp
# 2015-12-29 00:00:00 -0.00026 -1.525343e+09
# 2015-12-29 00:15:00 -0.00018 -1.566103e+09
# 2015-12-29 00:30:00 -0.00002 -8.013219e+08
# 2015-12-29 00:45:00 -0.00016 -8.951156e+08
# 2015-12-29 01:00:00 -0.00014 -1.508143e+09

# %%
def create_dataset(dataset, look_back=20):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back])
    return np.array(dataX), np.array(dataY)

# %%
colormap = plt.cm.inferno
plt.figure(figsize=(15,15))
plt.title('Pearson correlation of features', y=1.05, size=15)
sns.heatmap(df.corr(), linewidths=0.1, vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
plt.show()

plt.figure(figsize=(15,5))
corr = df.corr()
sns.heatmap(corr[corr.index == 'close'], linewidths=0.1, vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True);

# %%
from sklearn.ensemble import RandomForestRegressor

# Scale and create datasets
target_index = df.columns.tolist().index('close')
dataset = df.values.astype('float32')

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# Set look_back to 20 which is 5 hours (15min*20)
X, y = create_dataset(dataset, look_back=1)
y = y[:,target_index]
X = np.reshape(X, (X.shape[0], X.shape[2]))

# %%
forest = RandomForestRegressor(n_estimators = 100)
forest = forest.fit(X, y)

# %%
importances = forest.feature_importances_
std = np.std([forest.feature_importances_ for forest in forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

column_list = df.columns.tolist()
print("Feature ranking:")
for f in range(X.shape[1]-1):
    print("%d. %s %d (%f)" % (f, column_list[indices[f]], indices[f], importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure(figsize=(20,10))
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
       color="salmon", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 0. close 3 (0.812169)
# 1. ohlc_price 11 (0.077054)
# 2. avg_price 9 (0.072548)
# 3. high 1 (0.037153)
# 4. low 2 (0.000657)
# 5. open 0 (0.000073)
# 6. momentum 8 (0.000062)
# 7. range 10 (0.000060)
# 8. volume 4 (0.000045)
# 9. pca 13 (0.000045)
# 10. oc_diff 12 (0.000044)
# 11. hour 5 (0.000038)
# 12. week 7 (0.000028)

# %%
ax = df.plot(x=df.index, y='close', c='red', figsize=(40,10))
index = [str(item) for item in df.index]
plt.fill_between(x=index, y1='low',y2='high', data=df, alpha=0.4)
plt.show()

p = df[:200].copy()
ax = p.plot(x=p.index, y='close', c='red', figsize=(40,10))
index = [str(item) for item in p.index]
plt.fill_between(x=index, y1='low', y2='high', data=p, alpha=0.4)
plt.title('zoomed, first 200')
plt.show()

# %%
# Scale and create datasets
target_index = df.columns.tolist().index('close')
high_index = df.columns.tolist().index('high')
low_index = df.columns.tolist().index('low')
dataset = df.values.astype('float32')

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# Create y_scaler to inverse it later
y_scaler = MinMaxScaler(feature_range=(0, 1))
t_y = df['close'].values.astype('float32')
t_y = np.reshape(t_y, (-1, 1))
y_scaler = y_scaler.fit(t_y)
    
# Set look_back to 20 which is 5 hours (15min*20)
X, y = create_dataset(dataset, look_back=20)
y = y[:,target_index]

# %%
# Set training data size
# We have a large enough dataset. So divid into 98% training / 1%  development / 1% test sets
train_size = int(len(X) * 0.99)
trainX = X[:train_size]
trainY = y[:train_size]
testX = X[train_size:]
testY = y[train_size:]

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Input, LSTM, Dense

# create a small LSTM network
model = Sequential()
model.add(LSTM(20, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(LSTM(20, return_sequences=True))
model.add(LSTM(10, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(4, return_sequences=False))
model.add(Dense(4, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='relu'))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae', 'mse'])
print(model.summary())
# Out:
# Using Theano backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 20, 20)            2800
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 20, 20)            3280
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 20, 10)            1240
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 10)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 4)                 240
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 7,585
# Trainable params: 7,585
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import time
t0 = time.time()

# Save the best weight during training.
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_mean_squared_error', verbose=1, save_best_only=True, mode='min')

# Fit
callbacks_list = [checkpoint]
history = model.fit(trainX, trainY, epochs=200, batch_size=500, verbose=0, callbacks=callbacks_list, validation_split=0.1)

print("time_cost: " + str(time.time() - t0))
# Out:
# Epoch 00001: val_mean_squared_error improved from inf to 0.29839, saving model to weights.best.hdf5
#
# Epoch 00002: val_mean_squared_error improved from 0.29839 to 0.25378, saving model to weights.best.hdf5
#
# Epoch 00003: val_mean_squared_error improved from 0.25378 to 0.19013, saving model to weights.best.hdf5
#
# Epoch 00004: val_mean_squared_error improved from 0.19013 to 0.11887, saving model to weights.best.hdf5
#
# Epoch 00005: val_mean_squared_error improved from 0.11887 to 0.06488, saving model to weights.best.hdf5
#
# Epoch 00006: val_mean_squared_error improved from 0.06488 to 0.03489, saving model to weights.best.hdf5
#
# Epoch 00007: val_mean_squared_error improved from 0.03489 to 0.02137, saving model to weights.best.hdf5
#
# Epoch 00008: val_mean_squared_error improved from 0.02137 to 0.01662, saving model to weights.best.hdf5
#
# Epoch 00009: val_mean_squared_error improved from 0.01662 to 0.01526, saving model to weights.best.hdf5
#
# Epoch 00010: val_mean_squared_error improved from 0.01526 to 0.01520, saving model to weights.best.hdf5
#
# Epoch 00011: val_mean_squared_error improved from 0.01520 to 0.01507, saving model to weights.best.hdf5
#
# Epoch 00012: val_mean_squared_error did not improve from 0.01507
#
# Epoch 00013: val_mean_squared_error did not improve from 0.01507
#
# Epoch 00014: val_mean_squared_error did not improve from 0.01507
#
# Epoch 00015: val_mean_squared_error did not improve from 0.01507
#
# Epoch 00016: val_mean_squared_error did not improve from 0.01507
#
# Epoch 00017: val_mean_squared_error improved from 0.01507 to 0.01504, saving model to weights.best.hdf5
#
# Epoch 00018: val_mean_squared_error did not improve from 0.01504
#
# Epoch 00019: val_mean_squared_error did not improve from 0.01504
#
# Epoch 00020: val_mean_squared_error improved from 0.01504 to 0.00374, saving model to weights.best.hdf5
#
# Epoch 00021: val_mean_squared_error improved from 0.00374 to 0.00169, saving model to weights.best.hdf5
#
# Epoch 00022: val_mean_squared_error improved from 0.00169 to 0.00024, saving model to weights.best.hdf5
#
# Epoch 00023: val_mean_squared_error did not improve from 0.00024
#
# Epoch 00024: val_mean_squared_error improved from 0.00024 to 0.00020, saving model to weights.best.hdf5
#
# Epoch 00025: val_mean_squared_error improved from 0.00020 to 0.00016, saving model to weights.best.hdf5
#
# Epoch 00026: val_mean_squared_error did not improve from 0.00016
#
# Epoch 00027: val_mean_squared_error did not improve from 0.00016
#
# Epoch 00028: val_mean_squared_error improved from 0.00016 to 0.00012, saving model to weights.best.hdf5
#
# Epoch 00029: val_mean_squared_error did not improve from 0.00012
#
# Epoch 00030: val_mean_squared_error did not improve from 0.00012
#
# Epoch 00031: val_mean_squared_error did not improve from 0.00012
#
# Epoch 00032: val_mean_squared_error did not improve from 0.00012
#
# Epoch 00033: val_mean_squared_error did not improve from 0.00012
#
# Epoch 00034: val_mean_squared_error improved from 0.00012 to 0.00010, saving model to weights.best.hdf5
#
# Epoch 00035: val_mean_squared_error improved from 0.00010 to 0.00010, saving model to weights.best.hdf5
#
# Epoch 00036: val_mean_squared_error did not improve from 0.00010
#
# Epoch 00037: val_mean_squared_error did not improve from 0.00010
#
# Epoch 00038: val_mean_squared_error improved from 0.00010 to 0.00009, saving model to weights.best.hdf5
#
# Epoch 00039: val_mean_squared_error improved from 0.00009 to 0.00009, saving model to weights.best.hdf5
#
# Epoch 00040: val_mean_squared_error did not improve from 0.00009
#
# Epoch 00041: val_mean_squared_error did not improve from 0.00009
#
# Epoch 00042: val_mean_squared_error did not improve from 0.00009
#
# Epoch 00043: val_mean_squared_error did not improve from 0.00009
#
# Epoch 00044: val_mean_squared_error did not improve from 0.00009
#
# Epoch 00045: val_mean_squared_error did not improve from 0.00009
#
# Epoch 00046: val_mean_squared_error did not improve from 0.00009
#
# Epoch 00047: val_mean_squared_error improved from 0.00009 to 0.00008, saving model to weights.best.hdf5
#
# Epoch 00048: val_mean_squared_error did not improve from 0.00008
#
# Epoch 00049: val_mean_squared_error did not improve from 0.00008
#
# Epoch 00050: val_mean_squared_error did not improve from 0.00008
#
# Epoch 00051: val_mean_squared_error did not improve from 0.00008
#
# Epoch 00052: val_mean_squared_error did not improve from 0.00008
#
# Epoch 00053: val_mean_squared_error did not improve from 0.00008
#
# Epoch 00054: val_mean_squared_error did not improve from 0.00008
#
# Epoch 00055: val_mean_squared_error improved from 0.00008 to 0.00008, saving model to weights.best.hdf5
#
# Epoch 00056: val_mean_squared_error did not improve from 0.00008
#
# Epoch 00057: val_mean_squared_error improved from 0.00008 to 0.00007, saving model to weights.best.hdf5
#
# Epoch 00058: val_mean_squared_error did not improve from 0.00007
#
# Epoch 00059: val_mean_squared_error did not improve from 0.00007
#
# Epoch 00060: val_mean_squared_error did not improve from 0.00007
#
# Epoch 00061: val_mean_squared_error did not improve from 0.00007
#
# Epoch 00062: val_mean_squared_error did not improve from 0.00007
#
# Epoch 00063: val_mean_squared_error did not improve from 0.00007
#
# Epoch 00064: val_mean_squared_error improved from 0.00007 to 0.00007, saving model to weights.best.hdf5
#
# Epoch 00065: val_mean_squared_error did not improve from 0.00007
#
# Epoch 00066: val_mean_squared_error did not improve from 0.00007
#
# Epoch 00067: val_mean_squared_error did not improve from 0.00007
#
# Epoch 00068: val_mean_squared_error improved from 0.00007 to 0.00007, saving model to weights.best.hdf5
#
# Epoch 00069: val_mean_squared_error did not improve from 0.00007
#
# Epoch 00070: val_mean_squared_error did not improve from 0.00007
#
# Epoch 00071: val_mean_squared_error did not improve from 0.00007
#
# Epoch 00072: val_mean_squared_error improved from 0.00007 to 0.00006, saving model to weights.best.hdf5
#
# Epoch 00073: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00074: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00075: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00076: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00077: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00078: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00079: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00080: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00081: val_mean_squared_error improved from 0.00006 to 0.00006, saving model to weights.best.hdf5
#
# Epoch 00082: val_mean_squared_error improved from 0.00006 to 0.00006, saving model to weights.best.hdf5
#
# Epoch 00083: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00084: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00085: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00086: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00087: val_mean_squared_error improved from 0.00006 to 0.00006, saving model to weights.best.hdf5
#
# Epoch 00088: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00089: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00090: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00091: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00092: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00093: val_mean_squared_error improved from 0.00006 to 0.00006, saving model to weights.best.hdf5
#
# Epoch 00094: val_mean_squared_error did not improve from 0.00006
#
# Epoch 00095: val_mean_squared_error improved from 0.00006 to 0.00005, saving model to weights.best.hdf5
#
# Epoch 00096: val_mean_squared_error improved from 0.00005 to 0.00005, saving model to weights.best.hdf5
#
# Epoch 00097: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00098: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00099: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00100: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00101: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00102: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00103: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00104: val_mean_squared_error improved from 0.00005 to 0.00005, saving model to weights.best.hdf5
# Epoch 00105: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00106: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00107: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00108: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00109: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00110: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00111: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00112: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00113: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00114: val_mean_squared_error improved from 0.00005 to 0.00005, saving model to weights.best.hdf5
#
# Epoch 00115: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00116: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00117: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00118: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00119: val_mean_squared_error did not improve from 0.00005
#
# Epoch 00120: val_mean_squared_error improved from 0.00005 to 0.00004, saving model to weights.best.hdf5
#
# Epoch 00121: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00122: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00123: val_mean_squared_error improved from 0.00004 to 0.00004, saving model to weights.best.hdf5
#
# Epoch 00124: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00125: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00126: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00127: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00128: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00129: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00130: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00131: val_mean_squared_error improved from 0.00004 to 0.00004, saving model to weights.best.hdf5
#
# Epoch 00132: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00133: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00134: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00135: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00136: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00137: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00138: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00139: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00140: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00141: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00142: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00143: val_mean_squared_error improved from 0.00004 to 0.00004, saving model to weights.best.hdf5
#
# Epoch 00144: val_mean_squared_error did not improve from 0.00004
#
# Epoch 00145: val_mean_squared_error improved from 0.00004 to 0.00003, saving model to weights.best.hdf5
#
# Epoch 00146: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00147: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00148: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00149: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00150: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00151: val_mean_squared_error improved from 0.00003 to 0.00003, saving model to weights.best.hdf5
#
# Epoch 00152: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00153: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00154: val_mean_squared_error improved from 0.00003 to 0.00003, saving model to weights.best.hdf5
#
# Epoch 00155: val_mean_squared_error improved from 0.00003 to 0.00003, saving model to weights.best.hdf5
#
# Epoch 00156: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00157: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00158: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00159: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00160: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00161: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00162: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00163: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00164: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00165: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00166: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00167: val_mean_squared_error improved from 0.00003 to 0.00003, saving model to weights.best.hdf5
#
# Epoch 00168: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00169: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00170: val_mean_squared_error did not improve from 0.00003
#
# Epoch 00171: val_mean_squared_error improved from 0.00003 to 0.00002, saving model to weights.best.hdf5
#
# Epoch 00172: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00173: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00174: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00175: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00176: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00177: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00178: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00179: val_mean_squared_error improved from 0.00002 to 0.00002, saving model to weights.best.hdf5
#
# Epoch 00180: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00181: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00182: val_mean_squared_error improved from 0.00002 to 0.00002, saving model to weights.best.hdf5
#
# Epoch 00183: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00184: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00185: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00186: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00187: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00188: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00189: val_mean_squared_error improved from 0.00002 to 0.00002, saving model to weights.best.hdf5
#
# Epoch 00190: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00191: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00192: val_mean_squared_error improved from 0.00002 to 0.00002, saving model to weights.best.hdf5
#
# Epoch 00193: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00194: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00195: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00196: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00197: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00198: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00199: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00200: val_mean_squared_error did not improve from 0.00002
# time_cost: 821.7860310077667

# %%
epoch = len(history.history['loss'])
for k in list(history.history.keys()):
    if 'val' not in k:
        plt.figure(figsize=(40,10))
        plt.plot(history.history[k])
        plt.plot(history.history['val_' + k])
        plt.title(k)
        plt.ylabel(k)
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()

# %%
min(history.history['val_mean_absolute_error'])
# Out:
# 0.0029453454236230887

# %%
# Baby the model a bit
# Load the weight that worked the best
model.load_weights("weights.best.hdf5")

# Train again with decaying learning rate
from keras.callbacks import LearningRateScheduler
import keras.backend as K

def scheduler(epoch):
    if epoch%2==0 and epoch!=0:
        lr = float(K.get_value(model.optimizer.lr))
        K.set_value(model.optimizer.lr, lr*.9)
        print("lr changed to {}".format(lr*.9))
        #print("type: " + str(type(K.get_value(model.optimizer.lr)))
    return float(K.get_value(model.optimizer.lr))

scheduler(12)
lr_decay = LearningRateScheduler(scheduler)

callbacks_list = [checkpoint, lr_decay]
import time
t0 = time.time()
history = model.fit(trainX, trainY, epochs=int(epoch/3), batch_size=500, verbose=0, callbacks=callbacks_list, validation_split=0.1)
print("time cost optimized: " + str(time.time() - t0))
# Out:
# lr changed to 0.00038742052274756136
#
# Epoch 00001: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00002: val_mean_squared_error did not improve from 0.00002
# lr changed to 0.0003486784757114947
#
# Epoch 00003: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00004: val_mean_squared_error did not improve from 0.00002
# lr changed to 0.00031381062290165574
#
# Epoch 00005: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00006: val_mean_squared_error did not improve from 0.00002
# lr changed to 0.0002824295632308349
#
# Epoch 00007: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00008: val_mean_squared_error did not improve from 0.00002
# lr changed to 0.00025418660952709616
#
# Epoch 00009: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00010: val_mean_squared_error did not improve from 0.00002
# lr changed to 0.00022876793809700757
#
# Epoch 00011: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00012: val_mean_squared_error did not improve from 0.00002
# lr changed to 0.00020589114428730683
#
# Epoch 00013: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00014: val_mean_squared_error did not improve from 0.00002
# lr changed to 0.00018530203378759326
#
# Epoch 00015: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00016: val_mean_squared_error did not improve from 0.00002
# lr changed to 0.00016677183302817866
#
# Epoch 00017: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00018: val_mean_squared_error did not improve from 0.00002
# lr changed to 0.00015009464841568844
#
# Epoch 00019: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00020: val_mean_squared_error did not improve from 0.00002
# lr changed to 0.0001350851875031367
#
# Epoch 00021: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00022: val_mean_squared_error did not improve from 0.00002
# lr changed to 0.00012157666351413355
#
# Epoch 00023: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00024: val_mean_squared_error did not improve from 0.00002
# lr changed to 0.00010941899454337544
#
# Epoch 00025: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00026: val_mean_squared_error did not improve from 0.00002
# lr changed to 9.847709443420172e-05
#
# Epoch 00027: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00028: val_mean_squared_error did not improve from 0.00002
# lr changed to 8.862938630045391e-05
#
# Epoch 00029: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00030: val_mean_squared_error did not improve from 0.00002
# lr changed to 7.976644701557234e-05
#
# Epoch 00031: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00032: val_mean_squared_error did not improve from 0.00002
# lr changed to 7.178980231401511e-05
#
# Epoch 00033: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00034: val_mean_squared_error did not improve from 0.00002
# lr changed to 6.461082011810504e-05
#
# Epoch 00035: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00036: val_mean_squared_error did not improve from 0.00002
# lr changed to 5.8149741380475466e-05
#
# Epoch 00037: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00038: val_mean_squared_error did not improve from 0.00002
# lr changed to 5.233476658759173e-05
#
# Epoch 00039: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00040: val_mean_squared_error did not improve from 0.00002
# lr changed to 4.7101289601414466e-05
#
# Epoch 00041: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00042: val_mean_squared_error did not improve from 0.00002
# lr changed to 4.239116096869111e-05
#
# Epoch 00043: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00044: val_mean_squared_error did not improve from 0.00002
# lr changed to 3.815204618149437e-05
#
# Epoch 00045: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00046: val_mean_squared_error did not improve from 0.00002
# lr changed to 3.4336842873017304e-05
#
# Epoch 00047: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00048: val_mean_squared_error did not improve from 0.00002
# lr changed to 3.0903160222806036e-05
#
# Epoch 00049: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00050: val_mean_squared_error did not improve from 0.00002
# lr changed to 2.7812844200525434e-05
#
# Epoch 00051: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00052: val_mean_squared_error did not improve from 0.00002
# lr changed to 2.5031560107890984e-05
#
# Epoch 00053: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00054: val_mean_squared_error did not improve from 0.00002
# lr changed to 2.2528404588229024e-05
#
# Epoch 00055: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00056: val_mean_squared_error did not improve from 0.00002
# lr changed to 2.0275563474569936e-05
#
# Epoch 00057: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00058: val_mean_squared_error did not improve from 0.00002
# lr changed to 1.8248007290821987e-05
#
# Epoch 00059: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00060: val_mean_squared_error did not improve from 0.00002
# lr changed to 1.6423206398030745e-05
#
# Epoch 00061: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00062: val_mean_squared_error did not improve from 0.00002
# lr changed to 1.4780885430809576e-05
#
# Epoch 00063: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00064: val_mean_squared_error did not improve from 0.00002
# lr changed to 1.3302796560310526e-05
#
# Epoch 00065: val_mean_squared_error did not improve from 0.00002
#
# Epoch 00066: val_mean_squared_error did not improve from 0.00002
# time cost optimized: 220.6346890926361

# %%
epoch = len(history.history['loss'])
for k in list(history.history.keys()):
    if 'val' not in k:
        plt.figure(figsize=(40,10))
        plt.plot(history.history[k])
        plt.plot(history.history['val_' + k])
        plt.title(k)
        plt.ylabel(k)
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()

# %%
min(history.history['val_mean_absolute_error'])

"""
The variance should have improved slightly. However, unless the mean absolute error is not small enough. 
The model is still not an usable model in practice. 
This is mainly due to only using the sample data for training and limiting epoch to a few hundreds.
"""
# Out:
# 0.0030244040601449321

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Benchmark
model.load_weights("weights.best.hdf5")

pred = model.predict(testX)

predictions = pd.DataFrame()
predictions['predicted'] = pd.Series(np.reshape(pred, (pred.shape[0])))
predictions['actual'] = testY
predictions = predictions.astype(float)

predictions.plot(figsize=(20,10))
plt.show()

predictions['diff'] = predictions['predicted'] - predictions['actual']
plt.figure(figsize=(10,10))
sns.distplot(predictions['diff']);
plt.title('Distribution of differences between actual and prediction')
plt.show()

print("MSE : ", mean_squared_error(predictions['predicted'].values, predictions['actual'].values))
print("MAE : ", mean_absolute_error(predictions['predicted'].values, predictions['actual'].values))
predictions['diff'].describe()
# Out:
# MSE :  8.90694015983e-06
# MAE :  0.0021784119558
# count    149.000000
# mean      -0.001139
# std        0.002768
# min       -0.010796
# 25%       -0.002657
# 50%       -0.000820
# 75%        0.000124
# max        0.004440
# Name: diff, dtype: float64

# %%
pred = model.predict(testX)
pred = y_scaler.inverse_transform(pred)
close = y_scaler.inverse_transform(np.reshape(testY, (testY.shape[0], 1)))
predictions = pd.DataFrame()
predictions['predicted'] = pd.Series(np.reshape(pred, (pred.shape[0])))
predictions['close'] = pd.Series(np.reshape(close, (close.shape[0])))

p = df[-pred.shape[0]:].copy()
predictions.index = p.index
predictions = predictions.astype(float)
predictions = predictions.merge(p[['low', 'high']], right_index=True, left_index=True)

ax = predictions.plot(x=predictions.index, y='close', c='red', figsize=(40,10))
ax = predictions.plot(x=predictions.index, y='predicted', c='blue', figsize=(40,10), ax=ax)
index = [str(item) for item in predictions.index]
plt.fill_between(x=index, y1='low', y2='high', data=p, alpha=0.4)
plt.title('Prediction vs Actual (low and high as blue region)')
plt.show()

predictions['diff'] = predictions['predicted'] - predictions['close']
plt.figure(figsize=(10,10))
sns.distplot(predictions['diff']);
plt.title('Distribution of differences between actual and prediction ')
plt.show()

g = sns.jointplot("diff", "predicted", data=predictions, kind="kde", space=0)
plt.title('Distributtion of error and price')
plt.show()

# predictions['correct'] = (predictions['predicted'] <= predictions['high']) & (predictions['predicted'] >= predictions['low'])
# sns.factorplot(data=predictions, x='correct', kind='count')

print("MSE : ", mean_squared_error(predictions['predicted'].values, predictions['close'].values))
print("MAE : ", mean_absolute_error(predictions['predicted'].values, predictions['close'].values))
predictions['diff'].describe()
# Out:
# MSE :  7.0141033408e-08
# MAE :  0.000193308663848
# count    149.000000
# mean      -0.000101
# std        0.000246
# min       -0.000958
# 25%       -0.000236
# 50%       -0.000073
# 75%        0.000011
# max        0.000394
# Name: diff, dtype: float64
